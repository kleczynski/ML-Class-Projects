# %% [markdown]
# # Clustering

# %%
import sklearn
from sklearn.datasets import make_blobs
import numpy as np

# %%
help(make_blobs)
# Out:
# Help on function make_blobs in module sklearn.datasets._samples_generator:
#
# make_blobs(n_samples=100, n_features=2, *, centers=None, cluster_std=1.0, center_box=(-10.0, 10.0), shuffle=True, random_state=None, return_centers=False)
#     Generate isotropic Gaussian blobs for clustering.
#
#     Read more in the :ref:`User Guide <sample_generators>`.
#
#     Parameters
#     ----------
#     n_samples : int or array-like, default=100
#         If int, it is the total number of points equally divided among
#         clusters.
#         If array-like, each element of the sequence indicates
#         the number of samples per cluster.
#
#         .. versionchanged:: v0.20
#             one can now pass an array-like to the ``n_samples`` parameter
#
#     n_features : int, default=2
#         The number of features for each sample.
#
#     centers : int or ndarray of shape (n_centers, n_features), default=None
#         The number of centers to generate, or the fixed center locations.
# ...

# %%
X, y = make_blobs(n_samples=120, n_features=2, centers=4, cluster_std=0.40)

# %%
X.shape
# Out:
# (120, 2)

# %%
y.shape
# Out:
# (120,)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X[:,0],X[:, 1])

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(init='random', n_clusters=4, n_init=10, max_iter=120)

# %%
kmeans.fit(X)
# Out:
# KMeans(init='random', max_iter=120, n_clusters=4)

# %%
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=100, c='cyan', label ='Cluster 4')


plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='yellow', label = 'Centroids')

# %%
print(kmeans.inertia_)
# Out:
# 39.74651617488805

# %% [markdown]
# # K-means Example 2

# %%
X_2, y_2 = make_blobs(n_samples=300, n_features=5, centers=5, cluster_std=0.8)
plt.plot(X_2[:,0], X_2[:, 1], 'bo')

# %%
kmeans_2 = KMeans(
    init='random',
    n_clusters=5,
    n_init=20,
    max_iter=300)

y_kmeans_2 = kmeans_2.fit_predict(X_2)

# %%
plt.scatter(X_2[y_kmeans_2==0, 0], X_2[y_kmeans_2==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(X_2[y_kmeans_2==1, 0], X_2[y_kmeans_2==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(X_2[y_kmeans_2==2, 0], X_2[y_kmeans_2==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(X_2[y_kmeans_2==3, 0], X_2[y_kmeans_2==3, 1], s=100, c='cyan', label ='Cluster 4')
plt.scatter(X_2[y_kmeans_2==4, 0], X_2[y_kmeans_2==4, 1], s=100, c='black', label ='Cluster 5')


plt.scatter(kmeans_2.cluster_centers_[:, 0], kmeans_2.cluster_centers_[:, 1], s=100, c='purple', label = 'Centroids')

# %%
print(kmeans_2.inertia_)
# Out:
# 957.827453514868

# %% [markdown]
# # K-means ++

# %%
kmeans_2 = KMeans(
    init='k-means++',
    n_clusters=5,
    n_init=20,
    max_iter=300)

y_kmeans_2 = kmeans_2.fit_predict(X_2)


plt.scatter(X_2[y_kmeans_2==0, 0], X_2[y_kmeans_2==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(X_2[y_kmeans_2==1, 0], X_2[y_kmeans_2==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(X_2[y_kmeans_2==2, 0], X_2[y_kmeans_2==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(X_2[y_kmeans_2==3, 0], X_2[y_kmeans_2==3, 1], s=100, c='cyan', label ='Cluster 4')
plt.scatter(X_2[y_kmeans_2==4, 0], X_2[y_kmeans_2==4, 1], s=100, c='black', label ='Cluster 5')


plt.scatter(kmeans_2.cluster_centers_[:, 0], kmeans_2.cluster_centers_[:, 1], s=100, c='purple', label = 'Centroids')

# %%
print(kmeans_2.inertia_)
# Out:
# 957.827453514868

# %%
X_3, y_3 = make_blobs(n_samples=500, n_features=5, centers=5, cluster_std=0.8)
plt.scatter(X_3[:,0], X_3[:, 1])

# %%
kmeans_3 = KMeans(
    init='k-means++',
    n_clusters=5,
    n_init=10,
    max_iter=500)

y_kmeans_3 = kmeans_3.fit_predict(X_3)


plt.scatter(X_3[y_kmeans_3==0, 0], X_3[y_kmeans_3==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(X_3[y_kmeans_3==1, 0], X_3[y_kmeans_3==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(X_3[y_kmeans_3==2, 0], X_3[y_kmeans_3==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(X_3[y_kmeans_3==3, 0], X_3[y_kmeans_3==3, 1], s=100, c='cyan', label ='Cluster 4')
plt.scatter(X_3[y_kmeans_3==4, 0], X_3[y_kmeans_3==4, 1], s=100, c='black', label ='Cluster 5')


plt.scatter(kmeans_3.cluster_centers_[:, 0], kmeans_3.cluster_centers_[:, 1], s=100, c='purple', label = 'Centroids')

# %%
print(kmeans_3.inertia_)
# Out:
# 1555.722678047351

# %%
X_4, y_4 = make_blobs(n_samples=500, n_features=2, centers=2, cluster_std=0.8)
plt.scatter(X_4[:,0], X_4[:, 1])

# %%
kmeans_4 = KMeans(
    init='k-means++',
    n_clusters=2,
    n_init=10,
    max_iter=500)

y_kmeans_4 = kmeans_4.fit_predict(X_4)


plt.scatter(X_4[y_kmeans_4==0, 0], X_4[y_kmeans_4==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(X_4[y_kmeans_4==1, 0], X_4[y_kmeans_4==1, 1], s=100, c='blue', label ='Cluster 2')


plt.scatter(kmeans_4.cluster_centers_[:, 0], kmeans_4.cluster_centers_[:, 1], s=100, c='purple', label = 'Centroids')

# %%
print(kmeans_4.inertia_)
# Out:
# 631.4007651543861

# %% [markdown]
# # Elbow method

# %%
from sklearn.datasets import make_moons
import seaborn as sns
import pandas as pd
x, y = make_moons(1000, noise=.05, random_state=0)
X_moon = pd.DataFrame(x, columns = ['f1','f2'])
#TODO: Kmeans
kmeans = KMeans(n_clusters=20)
y_km = kmeans.fit_predict(x)
centers = kmeans.cluster_centers_
    
#Plot
X_moon['k_means'] = y_km
sns.lmplot(data=X_moon, x='f1', y='f2', fit_reg=False, hue = 'k_means', palette = ['#eb6c6a', '#6aeb6c']).set(title='Algorytm k-srednich')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.5)
plt.show()

# %%
plt.figure()
plt.scatter(x[:,0], x[:,1], c=y)
plt.title("Moon")
plt.show()

# %%
from sklearn.datasets import make_moons

ks = list(range(1,21))
inertia = []
for k in ks:
    kmeans = KMeans(n_clusters=k, init="k-means++").fit(x)
    inertia.append(kmeans.inertia_)
    
plt.figure()
plt.plot(ks, inertia, '-bo')
plt.xticks(ks)
plt.title("Elbow method")
plt.xlabel('k')
plt.ylabel('inertia')
plt.show()

# %%
X, y_true = make_blobs(n_samples=300, centers=5, cluster_std=0.8, random_state=0)
# Ex 1 - Plot data
plt.figure()
plt.scatter(X[:,0], X[:,1], c=y_true)
plt.title("Moon")
plt.show()

# %%
kmeans = KMeans(n_clusters=2, init='k-means++').fit(X)
pred = kmeans.predict(X)

plt.figure()
plt.scatter(X[:,0], X[:,1], c=pred)
plt.title("Moon - prediction")
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(X)
plt.figure(figsize=(40,10))
dendrogram(Z)
plt.show()

# %%
X, y_true = make_blobs(n_samples=50, centers=5, cluster_std=0.8, random_state=0)
Z = linkage(X)
plt.figure(figsize=(40,10))
dendrogram(Z)
plt.show()

# %%
data = pd.read_csv('shopping_data.csv')

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data = data[["Annual Income (k$)", "Spending Score (1-100)"]]

# %%
X = np.array(data)
plt.figure()
plt.scatter(X[:,0], X[:,1])
plt.title("Shopping data")
plt.show()

# %%
Z = linkage(X)
plt.figure(figsize=(40,10))
dendrogram(Z)
plt.show()

# %%
Z_ward = linkage(X, method='ward')
Z_complete = linkage(X, method='complete')
Z_average = linkage(X, method='average')
Z_single = linkage(X, method='single')
plt.figure(figsize=(40,10))
dendrogram(Z_ward)
plt.show()

# %%
plt.figure(figsize=(40,10))
dendrogram(Z_complete)
plt.show()

# %%
plt.figure(figsize=(40,10))
dendrogram(Z_average)
plt.show()

# %%
plt.figure(figsize=(40,10))
dendrogram(Z_single)
plt.show()

# %% [markdown]
# ### DBSCAN algorithm

# %%
from sklearn import  datasets
 
 
# ============
# Generate datasets.
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None
 
# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)
 
# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
datasets = [noisy_circles, noisy_moons, blobs, no_structure, aniso, varied]
names = ["Noisy circles", "Noisy moons", "Blobs", "No structure", "Aniso", "Varied"]
for dataset, name in zip(datasets, names):
  X, y = dataset
  kmeans = KMeans(n_clusters=2, init='k-means++')
  kmeans.fit(X)
  y_pred = kmeans.predict(X)
  plt.figure(figsize=(20,10))
  plt.subplot(1,3,1)
  plt.scatter(X[:, 0], X[:, 1], c=y_pred)
  plt.title("Kmeans")
  agg = AgglomerativeClustering(n_clusters = 2, linkage='ward').fit(X)
  agg_pred = agg.fit_predict(X)
  plt.subplot(1,3,2)
  plt.scatter(X[:, 0], X[:, 1], c=agg_pred)
  plt.title("AgglomerativeClustering")
  dbscan = DBSCAN().fit(X)
  dbscan_pred = dbscan.fit_predict(X)
  plt.subplot(1,3,3)
  plt.scatter(X[:, 0], X[:, 1], c=dbscan_pred)
  plt.title("DBSCAN")
  plt.suptitle(f"Name of dataset: {name}", fontsize=20)
  plt.show()
